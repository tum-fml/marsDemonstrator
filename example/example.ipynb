# %% [markdown]
# ## Example usage of MARS software demonstrator
#
# This notebook shows how to use the MARS software demonstrator. First the main application needs to be imported from the library. Furthermore, we will use pandas in this notebook to display the results of the computation.

# %%
import pandas as pd
import pathlib
import itertools

from marsDemonstrator.main_app import MainApplication

# %% [markdown]
# ## Configure computation
#
# Before running the computation two paramaters need to be set:
# - The stacker crane configuration
# - The computation mode
#
# ### Stacker crane configuration
# There are three possible stacker crane configurations:
# - 1-Mast moving direction left  (m1l)
# - 1-Mast moving direction right (m1r)
# - 2-Masts                       (m2)
#
# ### Computation mode
# There are two computation modes:
# - Proof mode: this mode computes the proofs for all of the defined SC configurations (proof)
# - Min. diameter mode: this mode computes the min. diameter that is needed to fulifill all proofs based on all other given parameters in the input file (min)
#
# ## Set input file and result file path
# Furthermore, the path to the input file and the desired path for the result file need to be set

# %%
# set configuration
CONFIG = "m1r" # 1-Mast moving direction right

# set computation mode
MODE = "proof" # proof mode

# input and result file path
INPUT_PATH = pathlib.Path.cwd() / "input_1_Mast.xlsx"
RESULT_PATH = pathlib.Path.cwd() / "result.xlsx"

# %% [markdown]
# ## Set up computation

# %%
# set up main application
main_application = MainApplication()

# read input file
main_application.input_file_path = INPUT_PATH
main_application.read_input_file(main_application.input_file_path)

# set a result file
main_application.output_file_path = RESULT_PATH

# set configuration ["m1l", "m1r", "m2"]
main_application.config = CONFIG

# extract information about moving direction from defined configuration
main_application.sc_direction = -1 if "l" in main_application.config else 1
if "m1" in main_application.config:
    main_application.config = "m1" 

# initialize gaussian processes
main_application.init_gps()

# %% [markdown]
# ## Run computation and read results using pandas

# %%
# computation mode 1 (proof mode)

# run computation
if MODE == "proof":
    main_application.computation_mode_1()
elif MODE == "min":
    main_application.computation_mode_2()
else:
    raise ValueError("Unrecognized computation mode")

# read results
results_summary = pd.read_excel(main_application.output_file_path, sheet_name="summary", header=None, index_col=[0, 1, 2])
results_detailed = pd.read_excel(main_application.output_file_path, sheet_name="results", header=None, index_col=[0, 1, 2])

# print errors
for error in list(itertools.chain(*main_application.input.error_report)):
    print(error)

# %% [markdown]
# ## Display results

# %%
# show result summary
with pd.option_context("display.max_rows", None):
    display(results_summary)
# Out:
#                                                                                                     3  \
# 0               1                2
# Results         Front Wheel      Static proof fulfilled                                         False
#                                  Fatigue proof fulfilled Prediction                              True
#                                  Fatigue proof fulfilled Upper Confidence Level                  True
#                 Rear Wheel       Static proof fulfilled                                         False
#                                  Fatigue proof fulfilled Prediction                              True
#                                  Fatigue proof fulfilled Upper Confidence Level                  True
#                 Rail             Static proof fulfilled                                         False
#                                  Fatigue proof fulfilled Prediction                             False
#                                  Fatigue proof fulfilled Upper Confidence Level                 False
# Input Variables EN-13001         Wheel-Geometry                                               W250-FL
#                                  Rail-Geometry                                                    S30
#                                  Wheel-Material                                      42CrMo4-hardened
#                                  Rail-Material                                                  S690Q
#                                  Decreasing-Factor-for-Non-Uniform-Pressure-Dist...              True
#                                  Mechanical-Drive-Factor-f_f4                                    True
#                                  Width of projecting non-contact area w [mm]                    False
#                                  Wheel-Skew-Angle [rad]                                         0.005
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...             False
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...             False
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...             13000
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...             20000
#                 SC Configuration SC-Height [m]                                              24.939792
#                                  SC-Center-of-Gravity-y [Fraction of SC-Height]              0.397534
#                                  Mast-Mass-Per-Height [kg/m]                               310.534233
#                                  Mast-Center-of-Gravity-x [Fraction of Wheel-Dis...               0.2
#                                  Mast-Mass-Total [kg]                                      9592.88213
#                                  Wheel-Distance [m]                                          6.985935
#                                  Traverse-Center-of-Gravity-x [Fraction of Wheel...          0.360322
#                                  Traverse-Mass-Per-Length [kg/m]                           235.360705
#                                  Traverse-Mass-Total [kg]                                 3620.844832
#                                  SC-Maximum-Acceleration [m/s²]                              1.133736
#                                  SC-Slip-Time [s]                                            0.675759
#                                  SC-Maximum-Velocity [m/s]                                   3.838798
#                                  Lift-Center-of-Gravity-x [m or Fraction of Whee...               1.2
#                                  Lift-Mass-Empyt [kg]                                     2351.035856
#                                  Load-Average-Mass [kg]                                     479.56428
#                                  Lift-Maximum-Acceleration [m/s²]                            1.520924
#                                  Rack-Length [m]                                           148.023378
#                                  Wheel-Number-of-Working-Cylces (planned life cy...           4000000
#                                  Rail-Number-of-Working-Cycles (planned life cycle)          12000000
#                                  Cycle Mode                                                      True
#
#                                                                                                     4  \
# 0               1                2
# Results         Front Wheel      Static proof fulfilled                                         False
#                                  Fatigue proof fulfilled Prediction                              True
#                                  Fatigue proof fulfilled Upper Confidence Level                  True
#                 Rear Wheel       Static proof fulfilled                                         False
#                                  Fatigue proof fulfilled Prediction                              True
#                                  Fatigue proof fulfilled Upper Confidence Level                  True
#                 Rail             Static proof fulfilled                                         False
#                                  Fatigue proof fulfilled Prediction                             False
#                                  Fatigue proof fulfilled Upper Confidence Level                 False
# Input Variables EN-13001         Wheel-Geometry                                               W500-FL
#                                  Rail-Geometry                                                    S33
#                                  Wheel-Material                                      42CrMo4-hardened
#                                  Rail-Material                                                  S690Q
#                                  Decreasing-Factor-for-Non-Uniform-Pressure-Dist...              True
#                                  Mechanical-Drive-Factor-f_f4                                    True
#                                  Width of projecting non-contact area w [mm]                       10
#                                  Wheel-Skew-Angle [rad]                                         0.005
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...             False
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...             False
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...             15000
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...             15000
#                 SC Configuration SC-Height [m]                                              29.846034
#                                  SC-Center-of-Gravity-y [Fraction of SC-Height]              0.387457
#                                  Mast-Mass-Per-Height [kg/m]                               311.826319
#                                  Mast-Center-of-Gravity-x [Fraction of Wheel-Dis...           0.27896
#                                  Mast-Mass-Total [kg]                                    13728.625095
#                                  Wheel-Distance [m]                                          4.866704
#                                  Traverse-Center-of-Gravity-x [Fraction of Wheel...          0.432636
#                                  Traverse-Mass-Per-Length [kg/m]                           208.806759
#                                  Traverse-Mass-Total [kg]                                 2311.158587
#                                  SC-Maximum-Acceleration [m/s²]                              2.425818
#                                  SC-Slip-Time [s]                                             0.51712
#                                  SC-Maximum-Velocity [m/s]                                   1.877634
#                                  Lift-Center-of-Gravity-x [m or Fraction of Whee...               3.2
#                                  Lift-Mass-Empyt [kg]                                            2600
#                                  Load-Average-Mass [kg]                                    342.075263
#                                  Lift-Maximum-Acceleration [m/s²]                            1.461136
#                                  Rack-Length [m]                                                   90
#                                  Wheel-Number-of-Working-Cylces (planned life cy...           4000000
#                                  Rail-Number-of-Working-Cycles (planned life cycle)          13000000
#                                  Cycle Mode                                                         2
#
#                                                                                                 5
# 0               1                2
# Results         Front Wheel      Static proof fulfilled                                     False
#                                  Fatigue proof fulfilled Prediction                          True
#                                  Fatigue proof fulfilled Upper Confidence Level              True
#                 Rear Wheel       Static proof fulfilled                                     False
#                                  Fatigue proof fulfilled Prediction                          True
#                                  Fatigue proof fulfilled Upper Confidence Level              True
#                 Rail             Static proof fulfilled                                     False
#                                  Fatigue proof fulfilled Prediction                          True
#                                  Fatigue proof fulfilled Upper Confidence Level             False
# Input Variables EN-13001         Wheel-Geometry                                             W1120
#                                  Rail-Geometry                                            S41-R10
#                                  Wheel-Material                                           34CrMo4
#                                  Rail-Material                                                C55
#                                  Decreasing-Factor-for-Non-Uniform-Pressure-Dist...          True
#                                  Mechanical-Drive-Factor-f_f4                                True
#                                  Width of projecting non-contact area w [mm]                   10
#                                  Wheel-Skew-Angle [rad]                                     0.005
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...         False
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...         False
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...         15000
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...         15000
#                 SC Configuration SC-Height [m]                                          29.846034
#                                  SC-Center-of-Gravity-y [Fraction of SC-Height]          0.387457
#                                  Mast-Mass-Per-Height [kg/m]                           311.826319
#                                  Mast-Center-of-Gravity-x [Fraction of Wheel-Dis...       0.27896
#                                  Mast-Mass-Total [kg]                                13728.625095
#                                  Wheel-Distance [m]                                      4.866704
#                                  Traverse-Center-of-Gravity-x [Fraction of Wheel...      0.432636
#                                  Traverse-Mass-Per-Length [kg/m]                       208.806759
#                                  Traverse-Mass-Total [kg]                             2311.158587
#                                  SC-Maximum-Acceleration [m/s²]                          2.425818
#                                  SC-Slip-Time [s]                                         0.51712
#                                  SC-Maximum-Velocity [m/s]                               1.877634
#                                  Lift-Center-of-Gravity-x [m or Fraction of Whee...           3.1
#                                  Lift-Mass-Empyt [kg]                                        2600
#                                  Load-Average-Mass [kg]                                342.075263
#                                  Lift-Maximum-Acceleration [m/s²]                        1.461136
#                                  Rack-Length [m]                                               90
#                                  Wheel-Number-of-Working-Cylces (planned life cy...       4000000
#                                  Rail-Number-of-Working-Cycles (planned life cycle)      13000000
#                                  Cycle Mode                                                     4

# %%
# show detailed results
with pd.option_context("display.max_rows", None):
    display(results_detailed)
# Out:
#                                                                                                     3  \
# 0               1                2
# Front Wheel     Static           Design-Contact-Force-F_sd_s [kN]                               13000
#                                  Limit-Design-Contact-Force-Static-F_rd_s [kN]              437.98681
#                                  Condition-Fullfilled                                           False
#                 Fatigue          Design-Contact-Force-F_sd_f [kN]                           80.459391
#                                  Reference-Contact-Force-F_u [kN]                           88.491213
#                                  Relative-Total-Number-of-Rolling-Contacts-v_c               0.375236
#                                  Contact-Force-Spectrum-Factor-k_c-Prediction                0.417303
#                                  Contact-Force-History-Parameter-s_c_Prediction              0.156587
#                                  Limit-Design-Contact-Force-Fatigue-F_rd_f-Predi...        140.307431
#                                  Condition-Fullfilled-Prediction                                 True
#                                  Contact-Force-Spectrum-Parameter-k_c-Upper-Conf...          0.446846
#                                  Contact-Force-History-Parameter-s_c_Upper-Confi...          0.167673
#                                  Limit-Force-F_rd_f-Prediction-Upper-Confidence-...         137.45756
#                                  Condition-Fullfilled-Upper-Confidence_Interval                  True
# Rear Wheel      Static           Design-Contact-Force-F_sd_s [kN]                               13000
#                                  Limit-Design-Contact-Force-Static-F_rd_s [kN]              437.98681
#                                  Condition-Fullfilled                                           False
#                 Fatigue          Design-Contact-Force-F_sd_f [kN]                          156.989551
#                                  Reference-Contact-Force-F_u [kN]                           88.491213
#                                  Relative-Total-Number-of-Rolling-Contacts-v_c               0.375236
#                                  Contact-Force-Spectrum-Factor-k_c-Prediction                 0.16613
#                                  Contact-Force-History-Parameter-s_c_Prediction              0.062338
#                                  Limit-Design-Contact-Force-Fatigue-F_rd_f-Predi...        184.961582
#                                  Condition-Fullfilled-Prediction                                 True
#                                  Contact-Force-Spectrum-Parameter-k_c-Upper-Conf...           0.19089
#                                  Contact-Force-History-Parameter-s_c_Upper-Confi...          0.071629
#                                  Limit-Force-F_rd_f-Prediction-Upper-Confidence-...        177.411153
#                                  Condition-Fullfilled-Upper-Confidence_Interval                  True
# Rail            Static           Design-Contact-Force-F_sd_s [kN]                               20000
#                                  Limit-Design-Contact-Force-Static-F_rd_s [kN]             349.160404
#                                  Condition-Fullfilled                                           False
#                 Fatigue          Design-Contact-Force-F_sd_f [kN]                          156.989551
#                                  Reference-Contact-Force-F_u [kN]                           70.544653
#                                  Relative-Total-Number-of-Rolling-Contacts-v_c                    7.5
#                                  Contact-Force-Spectrum-Factor-k_c-Prediction                0.197981
#                                  Contact-Force-History-Parameter-s_c_Prediction               1.48486
#                                  Limit-Design-Contact-Force-Fatigue-F_rd_f-Predi...         56.959445
#                                  Condition-Fullfilled-Prediction                                False
#                                  Contact-Force-Spectrum-Parameter-k_c-Upper-Conf...          0.276169
#                                  Contact-Force-History-Parameter-s_c_Upper-Confi...          2.071266
#                                  Limit-Force-F_rd_f-Prediction-Upper-Confidence-...         51.546675
#                                  Condition-Fullfilled-Upper-Confidence_Interval                 False
# Input Variables EN-13001         Wheel-Geometry                                               W250-FL
#                                  Rail-Geometry                                                    S30
#                                  Wheel-Material                                      42CrMo4-hardened
#                                  Rail-Material                                                  S690Q
#                                  Decreasing-Factor-for-Non-Uniform-Pressure-Dist...              True
#                                  Mechanical-Drive-Factor-f_f4                                    True
#                                  Width of projecting non-contact area w [mm]                    False
#                                  Wheel-Skew-Angle [rad]                                         0.005
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...             False
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...             False
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...             13000
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...             20000
#                 SC Configuration SC-Height [m]                                              24.939792
#                                  SC-Center-of-Gravity-y [Fraction of SC-Height]              0.397534
#                                  Mast-Mass-Per-Height [kg/m]                               310.534233
#                                  Mast-Center-of-Gravity-x [Fraction of Wheel-Dis...               0.2
#                                  Mast-Mass-Total [kg]                                      9592.88213
#                                  Wheel-Distance [m]                                          6.985935
#                                  Traverse-Center-of-Gravity-x [Fraction of Wheel...          0.360322
#                                  Traverse-Mass-Per-Length [kg/m]                           235.360705
#                                  Traverse-Mass-Total [kg]                                 3620.844832
#                                  SC-Maximum-Acceleration [m/s²]                              1.133736
#                                  SC-Slip-Time [s]                                            0.675759
#                                  SC-Maximum-Velocity [m/s]                                   3.838798
#                                  Lift-Center-of-Gravity-x [m or Fraction of Whee...               1.2
#                                  Lift-Mass-Empyt [kg]                                     2351.035856
#                                  Load-Average-Mass [kg]                                     479.56428
#                                  Lift-Maximum-Acceleration [m/s²]                            1.520924
#                                  Rack-Length [m]                                           148.023378
#                                  Wheel-Number-of-Working-Cylces (planned life cy...           4000000
#                                  Rail-Number-of-Working-Cycles (planned life cycle)          12000000
#                                  Cycle Mode                                                      True
#
#                                                                                                     4  \
# 0               1                2
# Front Wheel     Static           Design-Contact-Force-F_sd_s [kN]                               15000
#                                  Limit-Design-Contact-Force-Static-F_rd_s [kN]             615.971603
#                                  Condition-Fullfilled                                           False
#                 Fatigue          Design-Contact-Force-F_sd_f [kN]                          223.569338
#                                  Reference-Contact-Force-F_u [kN]                          124.451405
#                                  Relative-Total-Number-of-Rolling-Contacts-v_c               0.151008
#                                  Contact-Force-Spectrum-Factor-k_c-Prediction                0.067573
#                                  Contact-Force-History-Parameter-s_c_Prediction              0.010204
#                                  Limit-Design-Contact-Force-Fatigue-F_rd_f-Predi...        447.687634
#                                  Condition-Fullfilled-Prediction                                 True
#                                  Contact-Force-Spectrum-Parameter-k_c-Upper-Conf...           0.11634
#                                  Contact-Force-History-Parameter-s_c_Upper-Confi...          0.017568
#                                  Limit-Force-F_rd_f-Prediction-Upper-Confidence-...        380.354439
#                                  Condition-Fullfilled-Upper-Confidence_Interval                  True
# Rear Wheel      Static           Design-Contact-Force-F_sd_s [kN]                               15000
#                                  Limit-Design-Contact-Force-Static-F_rd_s [kN]             615.971603
#                                  Condition-Fullfilled                                           False
#                 Fatigue          Design-Contact-Force-F_sd_f [kN]                          258.139031
#                                  Reference-Contact-Force-F_u [kN]                          124.451405
#                                  Relative-Total-Number-of-Rolling-Contacts-v_c               0.151008
#                                  Contact-Force-Spectrum-Factor-k_c-Prediction                0.028123
#                                  Contact-Force-History-Parameter-s_c_Prediction              0.004247
#                                  Limit-Design-Contact-Force-Fatigue-F_rd_f-Predi...        582.358287
#                                  Condition-Fullfilled-Prediction                                 True
#                                  Contact-Force-Spectrum-Parameter-k_c-Upper-Conf...          0.064789
#                                  Contact-Force-History-Parameter-s_c_Upper-Confi...          0.009784
#                                  Limit-Force-F_rd_f-Prediction-Upper-Confidence-...        453.373778
#                                  Condition-Fullfilled-Upper-Confidence_Interval                  True
# Rail            Static           Design-Contact-Force-F_sd_s [kN]                               15000
#                                  Limit-Design-Contact-Force-Static-F_rd_s [kN]             491.048791
#                                  Condition-Fullfilled                                           False
#                 Fatigue          Design-Contact-Force-F_sd_f [kN]                          258.139031
#                                  Reference-Contact-Force-F_u [kN]                           99.211899
#                                  Relative-Total-Number-of-Rolling-Contacts-v_c                  8.125
#                                  Contact-Force-Spectrum-Factor-k_c-Prediction                0.036658
#                                  Contact-Force-History-Parameter-s_c_Prediction              0.297845
#                                  Limit-Design-Contact-Force-Fatigue-F_rd_f-Predi...        129.710194
#                                  Condition-Fullfilled-Prediction                                False
#                                  Contact-Force-Spectrum-Parameter-k_c-Upper-Conf...          0.142081
#                                  Contact-Force-History-Parameter-s_c_Upper-Confi...          1.154408
#                                  Limit-Force-F_rd_f-Prediction-Upper-Confidence-...         86.389959
#                                  Condition-Fullfilled-Upper-Confidence_Interval                 False
# Input Variables EN-13001         Wheel-Geometry                                               W500-FL
#                                  Rail-Geometry                                                    S33
#                                  Wheel-Material                                      42CrMo4-hardened
#                                  Rail-Material                                                  S690Q
#                                  Decreasing-Factor-for-Non-Uniform-Pressure-Dist...              True
#                                  Mechanical-Drive-Factor-f_f4                                    True
#                                  Width of projecting non-contact area w [mm]                       10
#                                  Wheel-Skew-Angle [rad]                                         0.005
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...             False
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...             False
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...             15000
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...             15000
#                 SC Configuration SC-Height [m]                                              29.846034
#                                  SC-Center-of-Gravity-y [Fraction of SC-Height]              0.387457
#                                  Mast-Mass-Per-Height [kg/m]                               311.826319
#                                  Mast-Center-of-Gravity-x [Fraction of Wheel-Dis...           0.27896
#                                  Mast-Mass-Total [kg]                                    13728.625095
#                                  Wheel-Distance [m]                                          4.866704
#                                  Traverse-Center-of-Gravity-x [Fraction of Wheel...          0.432636
#                                  Traverse-Mass-Per-Length [kg/m]                           208.806759
#                                  Traverse-Mass-Total [kg]                                 2311.158587
#                                  SC-Maximum-Acceleration [m/s²]                              2.425818
#                                  SC-Slip-Time [s]                                             0.51712
#                                  SC-Maximum-Velocity [m/s]                                   1.877634
#                                  Lift-Center-of-Gravity-x [m or Fraction of Whee...               3.2
#                                  Lift-Mass-Empyt [kg]                                            2600
#                                  Load-Average-Mass [kg]                                    342.075263
#                                  Lift-Maximum-Acceleration [m/s²]                            1.461136
#                                  Rack-Length [m]                                                   90
#                                  Wheel-Number-of-Working-Cylces (planned life cy...           4000000
#                                  Rail-Number-of-Working-Cycles (planned life cycle)          13000000
#                                  Cycle Mode                                                         2
#
#                                                                                                 5
# 0               1                2
# Front Wheel     Static           Design-Contact-Force-F_sd_s [kN]                           15000
#                                  Limit-Design-Contact-Force-Static-F_rd_s [kN]        1443.856607
#                                  Condition-Fullfilled                                       False
#                 Fatigue          Design-Contact-Force-F_sd_f [kN]                      222.887963
#                                  Reference-Contact-Force-F_u [kN]                      291.717968
#                                  Relative-Total-Number-of-Rolling-Contacts-v_c           0.100409
#                                  Contact-Force-Spectrum-Factor-k_c-Prediction             0.06829
#                                  Contact-Force-History-Parameter-s_c_Prediction          0.006857
#                                  Limit-Design-Contact-Force-Fatigue-F_rd_f-Predi...   1182.311424
#                                  Condition-Fullfilled-Prediction                             True
#                                  Contact-Force-Spectrum-Parameter-k_c-Upper-Conf...      0.116398
#                                  Contact-Force-History-Parameter-s_c_Upper-Confi...      0.011687
#                                  Limit-Force-F_rd_f-Prediction-Upper-Confidence-...   1007.522475
#                                  Condition-Fullfilled-Upper-Confidence_Interval              True
# Rear Wheel      Static           Design-Contact-Force-F_sd_s [kN]                           15000
#                                  Limit-Design-Contact-Force-Static-F_rd_s [kN]        1443.856607
#                                  Condition-Fullfilled                                       False
#                 Fatigue          Design-Contact-Force-F_sd_f [kN]                      258.820406
#                                  Reference-Contact-Force-F_u [kN]                      291.717968
#                                  Relative-Total-Number-of-Rolling-Contacts-v_c           0.100409
#                                  Contact-Force-Spectrum-Factor-k_c-Prediction            0.027658
#                                  Contact-Force-History-Parameter-s_c_Prediction          0.002777
#                                  Limit-Design-Contact-Force-Fatigue-F_rd_f-Predi...   1550.573622
#                                  Condition-Fullfilled-Prediction                             True
#                                  Contact-Force-Spectrum-Parameter-k_c-Upper-Conf...      0.063966
#                                  Contact-Force-History-Parameter-s_c_Upper-Confi...      0.006423
#                                  Limit-Force-F_rd_f-Prediction-Upper-Confidence-...    1205.74163
#                                  Condition-Fullfilled-Upper-Confidence_Interval              True
# Rail            Static           Design-Contact-Force-F_sd_s [kN]                           15000
#                                  Limit-Design-Contact-Force-Static-F_rd_s [kN]        1181.932506
#                                  Condition-Fullfilled                                       False
#                 Fatigue          Design-Contact-Force-F_sd_f [kN]                      258.820406
#                                  Reference-Contact-Force-F_u [kN]                      238.798608
#                                  Relative-Total-Number-of-Rolling-Contacts-v_c              8.125
#                                  Contact-Force-Spectrum-Factor-k_c-Prediction             0.03675
#                                  Contact-Force-History-Parameter-s_c_Prediction          0.298591
#                                  Limit-Design-Contact-Force-Fatigue-F_rd_f-Predi...    311.972495
#                                  Condition-Fullfilled-Prediction                             True
#                                  Contact-Force-Spectrum-Parameter-k_c-Upper-Conf...      0.140642
#                                  Contact-Force-History-Parameter-s_c_Upper-Confi...      1.142718
#                                  Limit-Force-F_rd_f-Prediction-Upper-Confidence-...    208.572645
#                                  Condition-Fullfilled-Upper-Confidence_Interval              True
# Input Variables EN-13001         Wheel-Geometry                                             W1120
#                                  Rail-Geometry                                            S41-R10
#                                  Wheel-Material                                           34CrMo4
#                                  Rail-Material                                                C55
#                                  Decreasing-Factor-for-Non-Uniform-Pressure-Dist...          True
#                                  Mechanical-Drive-Factor-f_f4                                True
#                                  Width of projecting non-contact area w [mm]                   10
#                                  Wheel-Skew-Angle [rad]                                     0.005
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...         False
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...         False
#                                  Wheel-Maximum-Contact-Force (Design-Contact-For...         15000
#                                  Rail-Maximum-Contact-Force (Design-Contact-Forc...         15000
#                 SC Configuration SC-Height [m]                                          29.846034
#                                  SC-Center-of-Gravity-y [Fraction of SC-Height]          0.387457
#                                  Mast-Mass-Per-Height [kg/m]                           311.826319
#                                  Mast-Center-of-Gravity-x [Fraction of Wheel-Dis...       0.27896
#                                  Mast-Mass-Total [kg]                                13728.625095
#                                  Wheel-Distance [m]                                      4.866704
#                                  Traverse-Center-of-Gravity-x [Fraction of Wheel...      0.432636
#                                  Traverse-Mass-Per-Length [kg/m]                       208.806759
#                                  Traverse-Mass-Total [kg]                             2311.158587
#                                  SC-Maximum-Acceleration [m/s²]                          2.425818
#                                  SC-Slip-Time [s]                                         0.51712
#                                  SC-Maximum-Velocity [m/s]                               1.877634
#                                  Lift-Center-of-Gravity-x [m or Fraction of Whee...           3.1
#                                  Lift-Mass-Empyt [kg]                                        2600
#                                  Load-Average-Mass [kg]                                342.075263
#                                  Lift-Maximum-Acceleration [m/s²]                        1.461136
#                                  Rack-Length [m]                                               90
#                                  Wheel-Number-of-Working-Cylces (planned life cy...       4000000
#                                  Rail-Number-of-Working-Cycles (planned life cycle)      13000000
#                                  Cycle Mode                                                     4
